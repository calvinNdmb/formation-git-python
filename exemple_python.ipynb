# %% [markdown]
# Exemple python

# %%
a =9
if a == 10:
    print("a is 10")
elif a > 10:
    print("a is greater than 10")
else:
    print("a is less than 10")
# Out:
# a is less than 10

# %%
b = 0
while b <5:
    print(b)
    b += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
a=0
while True:
    a+=1
    if a == 10:
        print("a is 10")
        break
# Out:
# a is 10

# %%
def name_of_function():
    print("This is a function")

name_of_function()
# Out:
# This is a function
